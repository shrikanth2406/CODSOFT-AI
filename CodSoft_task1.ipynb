# %%
pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator

# %%
import requests

# %%
while True:
    user_input = input("User: ")

    if user_input.lower() in ["hello", "hi"]:
        print("Chatbot: Hey there! How can I help you today?")

    elif "weather" in user_input.lower():
        print("Chatbot: I'm sorry, I don't have access to real-time weather information. But I'm here to chat with you!")

    elif "joke" in user_input.lower():
        print("Chatbot: Sure! Why don't scientists trust atoms? Because they make up everything!")

    elif "favorite color" in user_input.lower():
        print("Chatbot: I don't have a favorite color, but I love all the colors of the rainbow!")

    elif "movie" in user_input.lower():
     while True:
        print("Chatbot: I enjoy a wide range of movies. What's your favorite genre?")
        genre_input = input("User: ").lower()

        if genre_input == "action":
            print("Chatbot: Here are 5 top action movies: 1. The Dark Knight, 2. Mad Max: Fury Road, 3. Die Hard, 4. Inception, 5. Terminator 2: Judgment Day")
            break
        elif genre_input == "comedy":
            print("Chatbot: Here are 5 top comedy movies: 1. Airplane!, 2. The Hangover, 3. Bridesmaids, 4. Superbad, 5. Ferris Bueller's Day Off")
            break
        elif genre_input == "drama":
            print("Chatbot: Here are 5 top drama movies: 1. The Shawshank Redemption, 2. The Godfather, 3. Schindler's List, 4. Forrest Gump, 5. The Green Mile")
            break
        elif genre_input == "sci-fi":
            print("Chatbot: Here are 5 top sci-fi movies: 1. Blade Runner, 2. The Matrix, 3. Star Wars: A New Hope, 4. Interstellar, 5. The Fifth Element")
            break
        elif genre_input == "horror":
            print("Chatbot: Here are 5 top horror movies: 1. The Exorcist, 2. Psycho, 3. The Shining, 4. Get Out, 5. A Nightmare on Elm Street")
            break
        elif genre_input == "romance":
            print("Chatbot: Here are 5 top romance movies: 1. The Notebook, 2. Pride and Prejudice, 3. La La Land, 4. Before Sunrise, 5. Casablanca")
            break
        elif genre_input == "thriller":
            print("Chatbot: Here are 5 top thriller movies: 1. Seven, 2. Silence of the Lambs, 3. Memento, 4. Gone Girl, 5. The Usual Suspects")
            break
        elif genre_input == "animation":
            print("Chatbot: Here are 5 top animated movies: 1. The Lion King, 2. Toy Story, 3. Spirited Away, 4. Finding Nemo, 5. Shrek")
            break
        elif genre_input == "fantasy":
            print("Chatbot: Here are 5 top fantasy movies: 1. The Lord of the Rings: The Fellowship of the Ring, 2. Harry Potter and the Sorcerer's Stone, 3. The Princess Bride, 4. Pan's Labyrinth, 5. The Chronicles of Narnia: The Lion, the Witch and the Wardrobe")
            break
        else:
            print("Chatbot: I'm sorry, I'm not familiar with that genre. Please choose from action, comedy, drama, sci-fi, horror, romance, thriller, animation, fantasy, mystery, documentary, or musical.")


    elif "book" in user_input.lower():
        while True:
            print("Chatbot: I love books too! What genre are you interested in?")
            genre_input = input("User: ").lower()

            if genre_input == "fiction":
                print("Chatbot: Here are 5 top fiction books: 1. To Kill a Mockingbird by Harper Lee, 2. 1984 by George Orwell, 3. Pride and Prejudice by Jane Austen, 4. The Great Gatsby by F. Scott Fitzgerald, 5. The Catcher in the Rye by J.D. Salinger")
                break
            elif genre_input == "mystery":
                print("Chatbot: Here are 5 top mystery books: 1. The Girl with the Dragon Tattoo by Stieg Larsson, 2. Gone Girl by Gillian Flynn, 3. Sherlock Holmes by Arthur Conan Doyle, 4. The Da Vinci Code by Dan Brown, 5. The Hound of the Baskervilles by Arthur Conan Doyle")
                break
            elif genre_input == "romantic":
                print("Chatbot: Here are 5 top romantic books: 1. Pride and Prejudice by Jane Austen, 2. Wuthering Heights by Emily Brontë, 3. Sense and Sensibility by Jane Austen, 4. Romeo and Juliet by William Shakespeare, 5. The Fault in Our Stars by John Green")
                break
            elif genre_input == "science fiction":
                print("Chatbot: Here are 5 top science fiction books: 1. Dune by Frank Herbert, 2. Ender's Game by Orson Scott Card, 3. The Hitchhiker's Guide to the Galaxy by Douglas Adams, 4. Neuromancer by William Gibson, 5. The War of the Worlds by H.G. Wells")
                break
            elif genre_input == "fantasy":
                print("Chatbot: Here are 5 top fantasy books: 1. The Hobbit by J.R.R. Tolkien, 2. The Chronicles of Narnia by C.S. Lewis, 3. Harry Potter and the Sorcerer's Stone by J.K. Rowling, 4. A Game of Thrones by George R.R. Martin, 5. The Name of the Wind by Patrick Rothfuss")
                break
            elif genre_input == "historical fiction":
                print("Chatbot: Here are 5 top historical fiction books: 1. The Book Thief by Markus Zusak, 2. All the Light We Cannot See by Anthony Doerr, 3. The Nightingale by Kristin Hannah, 4. The Pillars of the Earth by Ken Follett, 5. The Other Boleyn Girl by Philippa Gregory")
                break
            else:
                print("Chatbot: I'm sorry, I'm not familiar with that genre. Please choose from the provided genres: fiction, mystery, romantic, science fiction, fantasy, historical fiction ?")


    elif "translate" in user_input.lower():
        print("Chatbot: Sure, I can help with translations. Please enter the word you want to translate and its language (e.g., 'bonjour French').")
        translation_request = input("User: ").split()

        if len(translation_request) == 2:
            word, language = translation_request
            translator = Translator()
            translation = translator.translate(word, src=language, dest='en')  # Specify source language
            print(f"Chatbot: Translating '{word}' from {language} to English: {translation.text}")
        else:
            print("Chatbot: I'm sorry, I didn't understand the request. Please provide a word and its language.")

    elif "sports" in user_input.lower():
        print("Chatbot: Do you have a favorite sport or team you'd like to talk about?")

    elif "technology" in user_input.lower():
        print("Chatbot: Technology is fascinating! Is there a specific tech topic you'd like to know more about?")

    elif "travel" in user_input.lower():
        print("Chatbot: Dreaming of a vacation? What kind of travel destination are you interested in?")

    elif "history" in user_input.lower():
        print("Chatbot: History is full of fascinating stories! Is there a particular historical period or event you'd like to learn more about?")

    elif "music" in user_input.lower() or "song" in user_input.lower():
        print("Chatbot: Do you have a favorite artist or genre?")
        music_input = input("User: ").lower()

        lastfm_api_key = "5985203f4a755bc8a01028766fa2661c"

        if music_input in ["pop", "rock", "hip-hop", "country", "jazz"]:
           url = f"http://ws.audioscrobbler.com/2.0/?method=tag.gettoptracks&tag={music_input}&api_key={lastfm_api_key}&format=json&limit=5"
           response = requests.get(url)
           data = response.json()

           if "tracks" in data and "track" in data["tracks"]:
            print(f"Chatbot: Here are 5 top songs in the {music_input} genre:")
            for i, track in enumerate(data["tracks"]["track"][:5], start=1):
                print(f"{i}. {track['name']} by {track['artist']['name']}")
           else:
               print("Chatbot: I'm sorry, I couldn't retrieve information for that genre.")

        else:
            url = f"http://ws.audioscrobbler.com/2.0/?method=artist.gettoptracks&artist={music_input}&api_key={lastfm_api_key}&format=json&limit=5"
            response = requests.get(url)
            data = response.json()

            if "toptracks" in data and "track" in data["toptracks"]:
                print(f"Chatbot: Here are 5 top songs by {music_input}:")
                for i, track in enumerate(data["toptracks"]["track"][:5], start=1):
                    print(f"{i}. {track['name']} by {track['artist']['name']}")
            else:
                print("Chatbot: I'm sorry, I couldn't retrieve information for that artist.")

    elif "exercise" in user_input.lower():
        print("Chatbot: Staying active is important! What type of exercise do you enjoy?")

    elif "pet" in user_input.lower():
        print("Chatbot: Pets are wonderful! Do you have a specific question about a type of pet or pet care?")

    elif "coding" in user_input.lower():
        print("Chatbot: Coding is a valuable skill! What programming language or coding topic are you interested in?")

    elif "food" in user_input.lower():
        print("Chatbot: Food is delightful! Do you have a favorite cuisine or dish?")

    elif "science" in user_input.lower():
        print("Chatbot: Science is fascinating! Is there a specific scientific topic you'd like to explore?")

    else:
        print("Chatbot: I'm sorry, I didn't quite understand. Can you please rephrase or ask something else?")
